# %% [markdown]
# ### Logistic Regression

# %%
import numpy as np
import pandas as pd
import seaborn as sns # this is used to color the graps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rate=pd.read_csv('ramen-ratings.csv')
rate
# Out:
#       Review #             Brand  \
# 0         2580         New Touch
# 1         2579          Just Way
# 2         2578            Nissin
# 3         2577           Wei Lih
# 4         2576    Ching's Secret
# 5         2575     Samyang Foods
# 6         2574           Acecook
# 7         2573       Ikeda Shoku
# 8         2572        Ripe'n'Dry
# 9         2571              KOKA
# 10        2570       Tao Kae Noi
# 11        2569          Yamachan
# 12        2568          Nongshim
# 13        2567            Nissin
# 14        2566            Nissin
# 15        2565              KOKA
# 16        2564              TRDP
# 17        2563          Yamachan
# 18        2562          Binh Tay
# 19        2561             Paldo
# 20        2560            Nissin
# 21        2559  Jackpot Teriyaki
# 22        2558              KOKA
# 23        2557          Yamachan
# 24        2556    Ching's Secret
# 25        2555     Samyang Foods
# 26        2554           Yum-Mie
# ...

# %%
rate.shape
# Out:
# (2580, 7)

# %%
rate.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
rate.isnull().sum().sum()
# Out:
# 2541

# %%
rate.dtypes
# Out:
# Review #     int64
# Brand       object
# Variety     object
# Style       object
# Country     object
# Stars       object
# Top Ten     object
# dtype: object

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
# Review #    2580 non-null int64
# Brand       2580 non-null object
# Variety     2580 non-null object
# Style       2578 non-null object
# Country     2580 non-null object
# Stars       2580 non-null object
# Top Ten     41 non-null object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
int_cols=rate.columns[rate.dtypes==np.int64]
print(int_cols)
int_cols.value_counts().sum()
# Out:
# Index(['Review #'], dtype='object')
# 1

# %%
float_cols=rate.columns[rate.dtypes==np.float64]
print(float_cols)
float_cols.value_counts().sum()
# Out:
# Index([], dtype='object')
# 0

# %%
object_cols=rate.columns[rate.dtypes==object]
print(float_cols)
object_cols.value_counts().sum()
# Out:
# Index([], dtype='object')
# 6
